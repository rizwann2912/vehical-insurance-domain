# %%
import pandas as pd
import pymongo

# %%
df= pd.read_csv('data.csv')
df.sample(5)
# Out:
#             id Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 356857  356858   Male   44                1         28.0                   0
# 358117  358118   Male   22                1         29.0                   1
# 148573  148574   Male   27                1         28.0                   1
# 243413  243414   Male   25                1          9.0                   0
# 173437  173438   Male   26                1          6.0                   1
#
#        Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  \
# 356857    1-2 Year            Yes         38621.0                 124.0
# 358117    < 1 Year             No         29040.0                 152.0
# 148573    < 1 Year             No         54006.0                 152.0
# 243413    < 1 Year            Yes         31373.0                 152.0
# 173437    < 1 Year             No         30121.0                 152.0
#
#         Vintage  Response
# 356857      291         0
# 358117      144         0
# 148573       36         0
# 243413      160         0
# 173437      271         0

# %%
data = df.to_dict(orient='records')
data
# Out:
# [{'id': 1,
#   'Gender': 'Male',
#   'Age': 44,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '> 2 Years',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 40454.0,
#   'Policy_Sales_Channel': 26.0,
#   'Vintage': 217,
#   'Response': 1},
#  {'id': 2,
#   'Gender': 'Male',
#   'Age': 76,
#   'Driving_License': 1,
#   'Region_Code': 3.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 33536.0,
#   'Policy_Sales_Channel': 26.0,
#   'Vintage': 183,
#   'Response': 0},
#  {'id': 3,
#   'Gender': 'Male',
#   'Age': 47,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '> 2 Years',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 38294.0,
#   'Policy_Sales_Channel': 26.0,
#   'Vintage': 27,
#   'Response': 1},
#  {'id': 4,
#   'Gender': 'Male',
#   'Age': 21,
#   'Driving_License': 1,
#   'Region_Code': 11.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 28619.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 203,
#   'Response': 0},
#  {'id': 5,
#   'Gender': 'Female',
#   'Age': 29,
#   'Driving_License': 1,
#   'Region_Code': 41.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 27496.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 39,
#   'Response': 0},
#  {'id': 6,
#   'Gender': 'Female',
#   'Age': 24,
#   'Driving_License': 1,
#   'Region_Code': 33.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 2630.0,
#   'Policy_Sales_Channel': 160.0,
#   'Vintage': 176,
#   'Response': 0},
#  {'id': 7,
#   'Gender': 'Male',
#   'Age': 23,
#   'Driving_License': 1,
#   'Region_Code': 11.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 23367.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 249,
#   'Response': 0},
#  {'id': 8,
#   'Gender': 'Female',
#   'Age': 56,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 32031.0,
#   'Policy_Sales_Channel': 26.0,
#   'Vintage': 72,
#   'Response': 1},
#  {'id': 9,
#   'Gender': 'Female',
#   'Age': 24,
#   'Driving_License': 1,
#   'Region_Code': 3.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 27619.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 28,
#   'Response': 0},
#  {'id': 10,
#   'Gender': 'Female',
#   'Age': 32,
#   'Driving_License': 1,
#   'Region_Code': 6.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 28771.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 80,
#   'Response': 0},
#  {'id': 11,
#   'Gender': 'Female',
#   'Age': 47,
#   'Driving_License': 1,
#   'Region_Code': 35.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 47576.0,
#   'Policy_Sales_Channel': 124.0,
#   'Vintage': 46,
#   'Response': 1},
#  {'id': 12,
#   'Gender': 'Female',
#   'Age': 24,
#   'Driving_License': 1,
#   'Region_Code': 50.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 48699.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 289,
#   'Response': 0},
#  {'id': 13,
#   'Gender': 'Female',
#   'Age': 41,
#   'Driving_License': 1,
#   'Region_Code': 15.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 31409.0,
#   'Policy_Sales_Channel': 14.0,
#   'Vintage': 221,
#   'Response': 0},
#  {'id': 14,
#   'Gender': 'Male',
#   'Age': 76,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 36770.0,
#   'Policy_Sales_Channel': 13.0,
#   'Vintage': 15,
#   'Response': 0},
#  {'id': 15,
#   'Gender': 'Male',
#   'Age': 71,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 46818.0,
#   'Policy_Sales_Channel': 30.0,
#   'Vintage': 58,
#   'Response': 0},
#  {'id': 16,
#   'Gender': 'Male',
#   'Age': 37,
#   'Driving_License': 1,
#   'Region_Code': 6.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 2630.0,
#   'Policy_Sales_Channel': 156.0,
#   'Vintage': 147,
#   'Response': 1},
#  {'id': 17,
#   'Gender': 'Female',
#   'Age': 25,
#   'Driving_License': 1,
#   'Region_Code': 45.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 26218.0,
#   'Policy_Sales_Channel': 160.0,
#   'Vintage': 256,
#   'Response': 0},
#  {'id': 18,
#   'Gender': 'Female',
#   'Age': 25,
#   'Driving_License': 1,
#   'Region_Code': 35.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 46622.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 299,
#   'Response': 0},
#  {'id': 19,
#   'Gender': 'Male',
#   'Age': 42,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 33667.0,
#   'Policy_Sales_Channel': 124.0,
#   'Vintage': 158,
#   'Response': 0},
#  {'id': 20,
#   'Gender': 'Female',
#   'Age': 60,
#   'Driving_License': 1,
#   'Region_Code': 33.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 32363.0,
#   'Policy_Sales_Channel': 124.0,
#   'Vintage': 102,
#   'Response': 1},
#  {'id': 21,
#   'Gender': 'Male',
#   'Age': 65,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 41184.0,
#   'Policy_Sales_Channel': 124.0,
#   'Vintage': 116,
#   'Response': 0},
#  {'id': 22,
#   'Gender': 'Male',
#   'Age': 49,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 50791.0,
#   'Policy_Sales_Channel': 124.0,
#   'Vintage': 177,
#   'Response': 0},
#  {'id': 23,
#   'Gender': 'Male',
#   'Age': 23,
#   'Driving_License': 1,
#   'Region_Code': 50.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 45283.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 232,
#   'Response': 0},
#  {'id': 24,
#   'Gender': 'Male',
#   'Age': 44,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 41852.0,
#   'Policy_Sales_Channel': 163.0,
#   'Vintage': 60,
#   'Response': 0},
#  {'id': 25,
#   'Gender': 'Male',
#   'Age': 34,
#   'Driving_License': 1,
#   'Region_Code': 15.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 38111.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 180,
#   'Response': 0},
#  {'id': 26,
#   'Gender': 'Female',
#   'Age': 21,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 61964.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 72,
#   'Response': 0},
#  {'id': 27,
#   'Gender': 'Female',
#   'Age': 51,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 38341.0,
#   'Policy_Sales_Channel': 124.0,
#   'Vintage': 49,
#   'Response': 1},
#  {'id': 28,
#   'Gender': 'Male',
#   'Age': 26,
#   'Driving_License': 1,
#   'Region_Code': 6.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 19135.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 57,
#   'Response': 0},
#  {'id': 29,
#   'Gender': 'Female',
#   'Age': 25,
#   'Driving_License': 1,
#   'Region_Code': 8.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 27946.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 223,
#   'Response': 0},
#  {'id': 30,
#   'Gender': 'Male',
#   'Age': 57,
#   'Driving_License': 1,
#   'Region_Code': 11.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 25679.0,
#   'Policy_Sales_Channel': 157.0,
#   'Vintage': 232,
#   'Response': 1},
#  {'id': 31,
#   'Gender': 'Female',
#   'Age': 26,
#   'Driving_License': 1,
#   'Region_Code': 8.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 2630.0,
#   'Policy_Sales_Channel': 160.0,
#   'Vintage': 136,
#   'Response': 0},
#  {'id': 32,
#   'Gender': 'Male',
#   'Age': 79,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 57444.0,
#   'Policy_Sales_Channel': 26.0,
#   'Vintage': 222,
#   'Response': 0},
#  {'id': 33,
#   'Gender': 'Female',
#   'Age': 48,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 36951.0,
#   'Policy_Sales_Channel': 122.0,
#   'Vintage': 149,
#   'Response': 0},
#  {'id': 34,
#   'Gender': 'Female',
#   'Age': 24,
#   'Driving_License': 1,
#   'Region_Code': 36.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 43129.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 49,
#   'Response': 0},
#  {'id': 35,
#   'Gender': 'Female',
#   'Age': 32,
#   'Driving_License': 1,
#   'Region_Code': 30.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 27638.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 169,
#   'Response': 0},
#  {'id': 36,
#   'Gender': 'Male',
#   'Age': 41,
#   'Driving_License': 1,
#   'Region_Code': 36.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 30039.0,
#   'Policy_Sales_Channel': 124.0,
#   'Vintage': 88,
#   'Response': 0},
#  {'id': 37,
#   'Gender': 'Male',
#   'Age': 71,
#   'Driving_License': 1,
#   'Region_Code': 8.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 40903.0,
#   'Policy_Sales_Channel': 19.0,
#   'Vintage': 253,
#   'Response': 0},
#  {'id': 38,
#   'Gender': 'Female',
#   'Age': 25,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 76251.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 107,
#   'Response': 0},
#  {'id': 39,
#   'Gender': 'Male',
#   'Age': 45,
#   'Driving_License': 1,
#   'Region_Code': 8.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 42297.0,
#   'Policy_Sales_Channel': 124.0,
#   'Vintage': 264,
#   'Response': 0},
#  {'id': 40,
#   'Gender': 'Male',
#   'Age': 72,
#   'Driving_License': 1,
#   'Region_Code': 41.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 32210.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 233,
#   'Response': 0},
#  {'id': 41,
#   'Gender': 'Male',
#   'Age': 30,
#   'Driving_License': 1,
#   'Region_Code': 30.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 24550.0,
#   'Policy_Sales_Channel': 124.0,
#   'Vintage': 45,
#   'Response': 0},
#  {'id': 42,
#   'Gender': 'Female',
#   'Age': 54,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 38560.0,
#   'Policy_Sales_Channel': 122.0,
#   'Vintage': 184,
#   'Response': 0},
#  {'id': 43,
#   'Gender': 'Male',
#   'Age': 27,
#   'Driving_License': 1,
#   'Region_Code': 41.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 21078.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 251,
#   'Response': 0},
#  {'id': 44,
#   'Gender': 'Female',
#   'Age': 38,
#   'Driving_License': 1,
#   'Region_Code': 35.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 2630.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 153,
#   'Response': 0},
#  {'id': 45,
#   'Gender': 'Female',
#   'Age': 26,
#   'Driving_License': 1,
#   'Region_Code': 30.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 31136.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 186,
#   'Response': 0},
#  {'id': 46,
#   'Gender': 'Male',
#   'Age': 56,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 34617.0,
#   'Policy_Sales_Channel': 124.0,
#   'Vintage': 71,
#   'Response': 0},
#  {'id': 47,
#   'Gender': 'Female',
#   'Age': 29,
#   'Driving_License': 1,
#   'Region_Code': 15.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 32923.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 34,
#   'Response': 0},
#  {'id': 48,
#   'Gender': 'Male',
#   'Age': 51,
#   'Driving_License': 1,
#   'Region_Code': 26.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 33761.0,
#   'Policy_Sales_Channel': 22.0,
#   'Vintage': 83,
#   'Response': 0},
#  {'id': 49,
#   'Gender': 'Female',
#   'Age': 25,
#   'Driving_License': 1,
#   'Region_Code': 15.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 38667.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 12,
#   'Response': 0},
#  {'id': 50,
#   'Gender': 'Male',
#   'Age': 48,
#   'Driving_License': 1,
#   'Region_Code': 3.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 38233.0,
#   'Policy_Sales_Channel': 124.0,
#   'Vintage': 246,
#   'Response': 0},
#  {'id': 51,
#   'Gender': 'Female',
#   'Age': 22,
#   'Driving_License': 1,
#   'Region_Code': 50.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 15052.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 141,
#   'Response': 0},
#  {'id': 52,
#   'Gender': 'Male',
#   'Age': 22,
#   'Driving_License': 1,
#   'Region_Code': 16.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 30673.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 216,
#   'Response': 0},
#  {'id': 53,
#   'Gender': 'Female',
#   'Age': 49,
#   'Driving_License': 1,
#   'Region_Code': 3.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 25553.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 130,
#   'Response': 0},
#  {'id': 54,
#   'Gender': 'Male',
#   'Age': 78,
#   'Driving_License': 1,
#   'Region_Code': 41.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 49491.0,
#   'Policy_Sales_Channel': 26.0,
#   'Vintage': 282,
#   'Response': 0},
#  {'id': 55,
#   'Gender': 'Female',
#   'Age': 44,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 45415.0,
#   'Policy_Sales_Channel': 13.0,
#   'Vintage': 73,
#   'Response': 0},
#  {'id': 56,
#   'Gender': 'Female',
#   'Age': 20,
#   'Driving_License': 1,
#   'Region_Code': 47.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 25380.0,
#   'Policy_Sales_Channel': 160.0,
#   'Vintage': 171,
#   'Response': 0},
#  {'id': 57,
#   'Gender': 'Male',
#   'Age': 39,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 57582.0,
#   'Policy_Sales_Channel': 26.0,
#   'Vintage': 141,
#   'Response': 0},
#  {'id': 58,
#   'Gender': 'Male',
#   'Age': 54,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 25205.0,
#   'Policy_Sales_Channel': 26.0,
#   'Vintage': 283,
#   'Response': 1},
#  {'id': 59,
#   'Gender': 'Female',
#   'Age': 62,
#   'Driving_License': 1,
#   'Region_Code': 48.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 2630.0,
#   'Policy_Sales_Channel': 15.0,
#   'Vintage': 295,
#   'Response': 0},
#  {'id': 60,
#   'Gender': 'Male',
#   'Age': 29,
#   'Driving_License': 1,
#   'Region_Code': 3.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 35463.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 165,
#   'Response': 0},
#  {'id': 61,
#   'Gender': 'Male',
#   'Age': 49,
#   'Driving_License': 1,
#   'Region_Code': 8.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 2630.0,
#   'Policy_Sales_Channel': 156.0,
#   'Vintage': 30,
#   'Response': 0},
#  {'id': 62,
#   'Gender': 'Female',
#   'Age': 20,
#   'Driving_License': 1,
#   'Region_Code': 50.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 36615.0,
#   'Policy_Sales_Channel': 160.0,
#   'Vintage': 218,
#   'Response': 0},
#  {'id': 63,
#   'Gender': 'Female',
#   'Age': 62,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '> 2 Years',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 33830.0,
#   'Policy_Sales_Channel': 26.0,
#   'Vintage': 130,
#   'Response': 0},
#  {'id': 64,
#   'Gender': 'Male',
#   'Age': 58,
#   'Driving_License': 1,
#   'Region_Code': 19.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 39661.0,
#   'Policy_Sales_Channel': 26.0,
#   'Vintage': 141,
#   'Response': 0},
#  {'id': 65,
#   'Gender': 'Male',
#   'Age': 39,
#   'Driving_License': 1,
#   'Region_Code': 15.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 37849.0,
#   'Policy_Sales_Channel': 124.0,
#   'Vintage': 22,
#   'Response': 0},
#  {'id': 66,
#   'Gender': 'Female',
#   'Age': 59,
#   'Driving_License': 1,
#   'Region_Code': 30.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 34426.0,
#   'Policy_Sales_Channel': 26.0,
#   'Vintage': 147,
#   'Response': 0},
#  {'id': 67,
#   'Gender': 'Male',
#   'Age': 41,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 42268.0,
#   'Policy_Sales_Channel': 154.0,
#   'Vintage': 36,
#   'Response': 0},
#  {'id': 68,
#   'Gender': 'Male',
#   'Age': 60,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 66338.0,
#   'Policy_Sales_Channel': 124.0,
#   'Vintage': 73,
#   'Response': 0},
#  {'id': 69,
#   'Gender': 'Male',
#   'Age': 63,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 61739.0,
#   'Policy_Sales_Channel': 124.0,
#   'Vintage': 79,
#   'Response': 0},
#  {'id': 70,
#   'Gender': 'Female',
#   'Age': 50,
#   'Driving_License': 1,
#   'Region_Code': 41.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 2630.0,
#   'Policy_Sales_Channel': 26.0,
#   'Vintage': 81,
#   'Response': 1},
#  {'id': 71,
#   'Gender': 'Male',
#   'Age': 44,
#   'Driving_License': 1,
#   'Region_Code': 47.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 46481.0,
#   'Policy_Sales_Channel': 16.0,
#   'Vintage': 100,
#   'Response': 0},
#  {'id': 72,
#   'Gender': 'Female',
#   'Age': 27,
#   'Driving_License': 1,
#   'Region_Code': 11.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 34587.0,
#   'Policy_Sales_Channel': 26.0,
#   'Vintage': 63,
#   'Response': 0},
#  {'id': 73,
#   'Gender': 'Female',
#   'Age': 23,
#   'Driving_License': 1,
#   'Region_Code': 39.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 40372.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 242,
#   'Response': 0},
#  {'id': 74,
#   'Gender': 'Male',
#   'Age': 50,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 27784.0,
#   'Policy_Sales_Channel': 26.0,
#   'Vintage': 277,
#   'Response': 0},
#  {'id': 75,
#   'Gender': 'Male',
#   'Age': 59,
#   'Driving_License': 1,
#   'Region_Code': 23.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 27865.0,
#   'Policy_Sales_Channel': 124.0,
#   'Vintage': 39,
#   'Response': 0},
#  {'id': 76,
#   'Gender': 'Female',
#   'Age': 59,
#   'Driving_License': 1,
#   'Region_Code': 26.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 35649.0,
#   'Policy_Sales_Channel': 122.0,
#   'Vintage': 136,
#   'Response': 0},
#  {'id': 77,
#   'Gender': 'Male',
#   'Age': 67,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 31993.0,
#   'Policy_Sales_Channel': 122.0,
#   'Vintage': 61,
#   'Response': 0},
#  {'id': 78,
#   'Gender': 'Female',
#   'Age': 27,
#   'Driving_License': 1,
#   'Region_Code': 33.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 35512.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 111,
#   'Response': 0},
#  {'id': 79,
#   'Gender': 'Male',
#   'Age': 29,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 42567.0,
#   'Policy_Sales_Channel': 26.0,
#   'Vintage': 167,
#   'Response': 1},
#  {'id': 80,
#   'Gender': 'Male',
#   'Age': 77,
#   'Driving_License': 1,
#   'Region_Code': 37.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 40651.0,
#   'Policy_Sales_Channel': 124.0,
#   'Vintage': 183,
#   'Response': 0},
#  {'id': 81,
#   'Gender': 'Male',
#   'Age': 54,
#   'Driving_License': 1,
#   'Region_Code': 26.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 35493.0,
#   'Policy_Sales_Channel': 22.0,
#   'Vintage': 74,
#   'Response': 0},
#  {'id': 82,
#   'Gender': 'Female',
#   'Age': 28,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 38529.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 235,
#   'Response': 0},
#  {'id': 83,
#   'Gender': 'Female',
#   'Age': 39,
#   'Driving_License': 1,
#   'Region_Code': 8.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 34735.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 131,
#   'Response': 0},
#  {'id': 84,
#   'Gender': 'Female',
#   'Age': 39,
#   'Driving_License': 1,
#   'Region_Code': 5.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 31760.0,
#   'Policy_Sales_Channel': 26.0,
#   'Vintage': 141,
#   'Response': 0},
#  {'id': 85,
#   'Gender': 'Male',
#   'Age': 69,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 29802.0,
#   'Policy_Sales_Channel': 122.0,
#   'Vintage': 158,
#   'Response': 0},
#  {'id': 86,
#   'Gender': 'Female',
#   'Age': 21,
#   'Driving_License': 1,
#   'Region_Code': 17.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 27756.0,
#   'Policy_Sales_Channel': 160.0,
#   'Vintage': 243,
#   'Response': 0},
#  {'id': 87,
#   'Gender': 'Female',
#   'Age': 54,
#   'Driving_License': 1,
#   'Region_Code': 47.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '> 2 Years',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 32873.0,
#   'Policy_Sales_Channel': 26.0,
#   'Vintage': 248,
#   'Response': 0},
#  {'id': 88,
#   'Gender': 'Male',
#   'Age': 25,
#   'Driving_License': 1,
#   'Region_Code': 23.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 23537.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 58,
#   'Response': 0},
#  {'id': 89,
#   'Gender': 'Female',
#   'Age': 23,
#   'Driving_License': 1,
#   'Region_Code': 35.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 27606.0,
#   'Policy_Sales_Channel': 160.0,
#   'Vintage': 114,
#   'Response': 0},
#  {'id': 90,
#   'Gender': 'Female',
#   'Age': 20,
#   'Driving_License': 1,
#   'Region_Code': 36.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 46275.0,
#   'Policy_Sales_Channel': 160.0,
#   'Vintage': 281,
#   'Response': 1},
#  {'id': 91,
#   'Gender': 'Female',
#   'Age': 25,
#   'Driving_License': 1,
#   'Region_Code': 50.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 31556.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 62,
#   'Response': 0},
#  {'id': 92,
#   'Gender': 'Female',
#   'Age': 26,
#   'Driving_License': 1,
#   'Region_Code': 30.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 31791.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 189,
#   'Response': 0},
#  {'id': 93,
#   'Gender': 'Male',
#   'Age': 77,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 36099.0,
#   'Policy_Sales_Channel': 124.0,
#   'Vintage': 139,
#   'Response': 0},
#  {'id': 94,
#   'Gender': 'Female',
#   'Age': 28,
#   'Driving_License': 1,
#   'Region_Code': 41.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 2630.0,
#   'Policy_Sales_Channel': 156.0,
#   'Vintage': 138,
#   'Response': 0},
#  {'id': 95,
#   'Gender': 'Female',
#   'Age': 23,
#   'Driving_License': 1,
#   'Region_Code': 15.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 41641.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 209,
#   'Response': 0},
#  {'id': 96,
#   'Gender': 'Female',
#   'Age': 23,
#   'Driving_License': 1,
#   'Region_Code': 30.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 26689.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 254,
#   'Response': 0},
#  {'id': 97,
#   'Gender': 'Male',
#   'Age': 50,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 46995.0,
#   'Policy_Sales_Channel': 52.0,
#   'Vintage': 291,
#   'Response': 0},
#  {'id': 98,
#   'Gender': 'Female',
#   'Age': 62,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '> 2 Years',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 41892.0,
#   'Policy_Sales_Channel': 155.0,
#   'Vintage': 114,
#   'Response': 0},
#  {'id': 99,
#   'Gender': 'Female',
#   'Age': 21,
#   'Driving_License': 1,
#   'Region_Code': 2.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 34274.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 79,
#   'Response': 0},
#  {'id': 100,
#   'Gender': 'Female',
#   'Age': 24,
#   'Driving_License': 1,
#   'Region_Code': 7.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 2630.0,
#   'Policy_Sales_Channel': 160.0,
#   'Vintage': 68,
#   'Response': 0},
#  {'id': 101,
#   'Gender': 'Male',
#   'Age': 52,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 36033.0,
#   'Policy_Sales_Channel': 26.0,
#   'Vintage': 92,
#   'Response': 0},
#  {'id': 102,
#   'Gender': 'Male',
#   'Age': 24,
#   'Driving_License': 1,
#   'Region_Code': 3.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 28139.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 52,
#   'Response': 0},
#  {'id': 103,
#   'Gender': 'Female',
#   'Age': 20,
#   'Driving_License': 1,
#   'Region_Code': 30.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 33227.0,
#   'Policy_Sales_Channel': 160.0,
#   'Vintage': 78,
#   'Response': 0},
#  {'id': 104,
#   'Gender': 'Female',
#   'Age': 22,
#   'Driving_License': 1,
#   'Region_Code': 8.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 39816.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 156,
#   'Response': 0},
#  {'id': 105,
#   'Gender': 'Male',
#   'Age': 29,
#   'Driving_License': 1,
#   'Region_Code': 41.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 43046.0,
#   'Policy_Sales_Channel': 163.0,
#   'Vintage': 222,
#   'Response': 0},
#  {'id': 106,
#   'Gender': 'Female',
#   'Age': 44,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 50521.0,
#   'Policy_Sales_Channel': 26.0,
#   'Vintage': 22,
#   'Response': 1},
#  {'id': 107,
#   'Gender': 'Female',
#   'Age': 23,
#   'Driving_License': 1,
#   'Region_Code': 41.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 36674.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 158,
#   'Response': 0},
#  {'id': 108,
#   'Gender': 'Male',
#   'Age': 31,
#   'Driving_License': 1,
#   'Region_Code': 29.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 28867.0,
#   'Policy_Sales_Channel': 124.0,
#   'Vintage': 247,
#   'Response': 0},
#  {'id': 109,
#   'Gender': 'Male',
#   'Age': 72,
#   'Driving_License': 1,
#   'Region_Code': 46.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 28698.0,
#   'Policy_Sales_Channel': 30.0,
#   'Vintage': 216,
#   'Response': 0},
#  {'id': 110,
#   'Gender': 'Male',
#   'Age': 45,
#   'Driving_License': 1,
#   'Region_Code': 35.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 2630.0,
#   'Policy_Sales_Channel': 124.0,
#   'Vintage': 275,
#   'Response': 0},
#  {'id': 111,
#   'Gender': 'Male',
#   'Age': 27,
#   'Driving_License': 1,
#   'Region_Code': 8.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 31428.0,
#   'Policy_Sales_Channel': 122.0,
#   'Vintage': 77,
#   'Response': 0},
#  {'id': 112,
#   'Gender': 'Female',
#   'Age': 48,
#   'Driving_License': 1,
#   'Region_Code': 46.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '> 2 Years',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 37379.0,
#   'Policy_Sales_Channel': 11.0,
#   'Vintage': 139,
#   'Response': 0},
#  {'id': 113,
#   'Gender': 'Female',
#   'Age': 33,
#   'Driving_License': 1,
#   'Region_Code': 30.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 24998.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 181,
#   'Response': 0},
#  {'id': 114,
#   'Gender': 'Male',
#   'Age': 50,
#   'Driving_License': 1,
#   'Region_Code': 30.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 34271.0,
#   'Policy_Sales_Channel': 26.0,
#   'Vintage': 229,
#   'Response': 1},
#  {'id': 115,
#   'Gender': 'Female',
#   'Age': 28,
#   'Driving_License': 1,
#   'Region_Code': 30.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 32830.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 275,
#   'Response': 0},
#  {'id': 116,
#   'Gender': 'Female',
#   'Age': 32,
#   'Driving_License': 1,
#   'Region_Code': 46.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 34810.0,
#   'Policy_Sales_Channel': 26.0,
#   'Vintage': 166,
#   'Response': 0},
#  {'id': 117,
#   'Gender': 'Male',
#   'Age': 69,
#   'Driving_License': 1,
#   'Region_Code': 46.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 2630.0,
#   'Policy_Sales_Channel': 11.0,
#   'Vintage': 16,
#   'Response': 0},
#  {'id': 118,
#   'Gender': 'Female',
#   'Age': 32,
#   'Driving_License': 1,
#   'Region_Code': 27.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 22838.0,
#   'Policy_Sales_Channel': 151.0,
#   'Vintage': 295,
#   'Response': 0},
#  {'id': 119,
#   'Gender': 'Female',
#   'Age': 23,
#   'Driving_License': 1,
#   'Region_Code': 29.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 37983.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 23,
#   'Response': 0},
#  {'id': 120,
#   'Gender': 'Female',
#   'Age': 23,
#   'Driving_License': 1,
#   'Region_Code': 25.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 2630.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 149,
#   'Response': 0},
#  {'id': 121,
#   'Gender': 'Male',
#   'Age': 39,
#   'Driving_License': 1,
#   'Region_Code': 3.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 37239.0,
#   'Policy_Sales_Channel': 26.0,
#   'Vintage': 216,
#   'Response': 1},
#  {'id': 122,
#   'Gender': 'Female',
#   'Age': 39,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 37243.0,
#   'Policy_Sales_Channel': 124.0,
#   'Vintage': 31,
#   'Response': 0},
#  {'id': 123,
#   'Gender': 'Male',
#   'Age': 37,
#   'Driving_License': 1,
#   'Region_Code': 13.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 30440.0,
#   'Policy_Sales_Channel': 124.0,
#   'Vintage': 293,
#   'Response': 0},
#  {'id': 124,
#   'Gender': 'Male',
#   'Age': 34,
#   'Driving_License': 1,
#   'Region_Code': 18.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 38232.0,
#   'Policy_Sales_Channel': 124.0,
#   'Vintage': 156,
#   'Response': 1},
#  {'id': 125,
#   'Gender': 'Male',
#   'Age': 23,
#   'Driving_License': 1,
#   'Region_Code': 15.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 25605.0,
#   'Policy_Sales_Channel': 160.0,
#   'Vintage': 256,
#   'Response': 0},
#  {'id': 126,
#   'Gender': 'Male',
#   'Age': 49,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 2630.0,
#   'Policy_Sales_Channel': 124.0,
#   'Vintage': 88,
#   'Response': 0},
#  {'id': 127,
#   'Gender': 'Male',
#   'Age': 23,
#   'Driving_License': 1,
#   'Region_Code': 41.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 33307.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 147,
#   'Response': 0},
#  {'id': 128,
#   'Gender': 'Female',
#   'Age': 22,
#   'Driving_License': 1,
#   'Region_Code': 25.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 23955.0,
#   'Policy_Sales_Channel': 160.0,
#   'Vintage': 22,
#   'Response': 0},
#  {'id': 129,
#   'Gender': 'Female',
#   'Age': 22,
#   'Driving_License': 1,
#   'Region_Code': 20.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 2630.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 219,
#   'Response': 0},
#  {'id': 130,
#   'Gender': 'Female',
#   'Age': 27,
#   'Driving_License': 1,
#   'Region_Code': 41.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 22371.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 50,
#   'Response': 0},
#  {'id': 131,
#   'Gender': 'Male',
#   'Age': 50,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 57389.0,
#   'Policy_Sales_Channel': 26.0,
#   'Vintage': 155,
#   'Response': 1},
#  {'id': 132,
#   'Gender': 'Female',
#   'Age': 27,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 30005.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 92,
#   'Response': 0},
#  {'id': 133,
#   'Gender': 'Male',
#   'Age': 28,
#   'Driving_License': 1,
#   'Region_Code': 37.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 32600.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 131,
#   'Response': 0},
#  {'id': 134,
#   'Gender': 'Female',
#   'Age': 25,
#   'Driving_License': 1,
#   'Region_Code': 49.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 31680.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 66,
#   'Response': 0},
#  {'id': 135,
#   'Gender': 'Female',
#   'Age': 27,
#   'Driving_License': 1,
#   'Region_Code': 8.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 40651.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 260,
#   'Response': 0},
#  {'id': 136,
#   'Gender': 'Female',
#   'Age': 43,
#   'Driving_License': 1,
#   'Region_Code': 41.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 2630.0,
#   'Policy_Sales_Channel': 26.0,
#   'Vintage': 19,
#   'Response': 1},
#  {'id': 137,
#   'Gender': 'Female',
#   'Age': 59,
#   'Driving_License': 1,
#   'Region_Code': 39.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 32775.0,
#   'Policy_Sales_Channel': 124.0,
#   'Vintage': 158,
#   'Response': 0},
#  {'id': 138,
#   'Gender': 'Female',
#   'Age': 23,
#   'Driving_License': 1,
#   'Region_Code': 36.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 33638.0,
#   'Policy_Sales_Channel': 160.0,
#   'Vintage': 22,
#   'Response': 0},
#  {'id': 139,
#   'Gender': 'Male',
#   'Age': 36,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 2630.0,
#   'Policy_Sales_Channel': 26.0,
#   'Vintage': 258,
#   'Response': 0},
#  {'id': 140,
#   'Gender': 'Male',
#   'Age': 21,
#   'Driving_License': 1,
#   'Region_Code': 29.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 62164.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 116,
#   'Response': 0},
#  {'id': 141,
#   'Gender': 'Female',
#   'Age': 21,
#   'Driving_License': 1,
#   'Region_Code': 46.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 27528.0,
#   'Policy_Sales_Channel': 160.0,
#   'Vintage': 117,
#   'Response': 0},
#  {'id': 142,
#   'Gender': 'Female',
#   'Age': 47,
#   'Driving_License': 1,
#   'Region_Code': 41.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 42080.0,
#   'Policy_Sales_Channel': 124.0,
#   'Vintage': 62,
#   'Response': 0},
#  {'id': 143,
#   'Gender': 'Male',
#   'Age': 25,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 36202.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 193,
#   'Response': 0},
#  {'id': 144,
#   'Gender': 'Female',
#   'Age': 32,
#   'Driving_License': 1,
#   'Region_Code': 46.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 27320.0,
#   'Policy_Sales_Channel': 156.0,
#   'Vintage': 204,
#   'Response': 0},
#  {'id': 145,
#   'Gender': 'Male',
#   'Age': 21,
#   'Driving_License': 1,
#   'Region_Code': 3.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 40511.0,
#   'Policy_Sales_Channel': 160.0,
#   'Vintage': 212,
#   'Response': 0},
#  {'id': 146,
#   'Gender': 'Male',
#   'Age': 23,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 56589.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 144,
#   'Response': 0},
#  {'id': 147,
#   'Gender': 'Female',
#   'Age': 27,
#   'Driving_License': 1,
#   'Region_Code': 30.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 33780.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 246,
#   'Response': 0},
#  {'id': 148,
#   'Gender': 'Male',
#   'Age': 20,
#   'Driving_License': 1,
#   'Region_Code': 39.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 28329.0,
#   'Policy_Sales_Channel': 160.0,
#   'Vintage': 78,
#   'Response': 0},
#  {'id': 149,
#   'Gender': 'Female',
#   'Age': 38,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 34471.0,
#   'Policy_Sales_Channel': 124.0,
#   'Vintage': 234,
#   'Response': 1},
#  {'id': 150,
#   'Gender': 'Female',
#   'Age': 22,
#   'Driving_License': 1,
#   'Region_Code': 11.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 76651.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 258,
#   'Response': 0},
#  {'id': 151,
#   'Gender': 'Male',
#   'Age': 25,
#   'Driving_License': 1,
#   'Region_Code': 8.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 54385.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 206,
#   'Response': 0},
#  {'id': 152,
#   'Gender': 'Male',
#   'Age': 27,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 26732.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 282,
#   'Response': 0},
#  {'id': 153,
#   'Gender': 'Male',
#   'Age': 51,
#   'Driving_License': 1,
#   'Region_Code': 19.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 2630.0,
#   'Policy_Sales_Channel': 124.0,
#   'Vintage': 228,
#   'Response': 0},
#  {'id': 154,
#   'Gender': 'Male',
#   'Age': 53,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 40397.0,
#   'Policy_Sales_Channel': 122.0,
#   'Vintage': 156,
#   'Response': 0},
#  {'id': 155,
#   'Gender': 'Female',
#   'Age': 24,
#   'Driving_License': 1,
#   'Region_Code': 22.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 34591.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 125,
#   'Response': 0},
#  {'id': 156,
#   'Gender': 'Female',
#   'Age': 49,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 32771.0,
#   'Policy_Sales_Channel': 154.0,
#   'Vintage': 29,
#   'Response': 0},
#  {'id': 157,
#   'Gender': 'Female',
#   'Age': 41,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 54740.0,
#   'Policy_Sales_Channel': 124.0,
#   'Vintage': 212,
#   'Response': 1},
#  {'id': 158,
#   'Gender': 'Male',
#   'Age': 41,
#   'Driving_License': 1,
#   'Region_Code': 35.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 25112.0,
#   'Policy_Sales_Channel': 154.0,
#   'Vintage': 221,
#   'Response': 0},
#  {'id': 159,
#   'Gender': 'Female',
#   'Age': 23,
#   'Driving_License': 1,
#   'Region_Code': 47.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 28737.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 18,
#   'Response': 0},
#  {'id': 160,
#   'Gender': 'Female',
#   'Age': 31,
#   'Driving_License': 1,
#   'Region_Code': 15.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 25908.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 84,
#   'Response': 0},
#  {'id': 161,
#   'Gender': 'Male',
#   'Age': 20,
#   'Driving_License': 1,
#   'Region_Code': 3.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 41914.0,
#   'Policy_Sales_Channel': 160.0,
#   'Vintage': 206,
#   'Response': 0},
#  {'id': 162,
#   'Gender': 'Male',
#   'Age': 70,
#   'Driving_License': 1,
#   'Region_Code': 25.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 2630.0,
#   'Policy_Sales_Channel': 124.0,
#   'Vintage': 230,
#   'Response': 0},
#  {'id': 163,
#   'Gender': 'Male',
#   'Age': 78,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 42462.0,
#   'Policy_Sales_Channel': 26.0,
#   'Vintage': 54,
#   'Response': 0},
#  {'id': 164,
#   'Gender': 'Female',
#   'Age': 31,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 29395.0,
#   'Policy_Sales_Channel': 26.0,
#   'Vintage': 123,
#   'Response': 0},
#  {'id': 165,
#   'Gender': 'Female',
#   'Age': 48,
#   'Driving_License': 1,
#   'Region_Code': 36.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 2630.0,
#   'Policy_Sales_Channel': 124.0,
#   'Vintage': 189,
#   'Response': 0},
#  {'id': 166,
#   'Gender': 'Male',
#   'Age': 25,
#   'Driving_License': 1,
#   'Region_Code': 30.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 29396.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 22,
#   'Response': 0},
#  {'id': 167,
#   'Gender': 'Female',
#   'Age': 28,
#   'Driving_License': 1,
#   'Region_Code': 44.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 37570.0,
#   'Policy_Sales_Channel': 156.0,
#   'Vintage': 258,
#   'Response': 1},
#  {'id': 168,
#   'Gender': 'Female',
#   'Age': 26,
#   'Driving_License': 1,
#   'Region_Code': 8.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 89282.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 101,
#   'Response': 0},
#  {'id': 169,
#   'Gender': 'Female',
#   'Age': 60,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 30386.0,
#   'Policy_Sales_Channel': 26.0,
#   'Vintage': 114,
#   'Response': 0},
#  {'id': 170,
#   'Gender': 'Female',
#   'Age': 28,
#   'Driving_License': 1,
#   'Region_Code': 8.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 31454.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 86,
#   'Response': 0},
#  {'id': 171,
#   'Gender': 'Male',
#   'Age': 23,
#   'Driving_License': 1,
#   'Region_Code': 36.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 52462.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 243,
#   'Response': 0},
#  {'id': 172,
#   'Gender': 'Male',
#   'Age': 22,
#   'Driving_License': 1,
#   'Region_Code': 36.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 36352.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 13,
#   'Response': 0},
#  {'id': 173,
#   'Gender': 'Female',
#   'Age': 50,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 36282.0,
#   'Policy_Sales_Channel': 26.0,
#   'Vintage': 237,
#   'Response': 0},
#  {'id': 174,
#   'Gender': 'Female',
#   'Age': 33,
#   'Driving_License': 1,
#   'Region_Code': 36.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 40899.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 85,
#   'Response': 0},
#  {'id': 175,
#   'Gender': 'Male',
#   'Age': 24,
#   'Driving_License': 1,
#   'Region_Code': 35.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 23540.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 98,
#   'Response': 0},
#  {'id': 176,
#   'Gender': 'Female',
#   'Age': 22,
#   'Driving_License': 1,
#   'Region_Code': 36.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 34527.0,
# ...
#   'Annual_Premium': 37449.0,
#   'Policy_Sales_Channel': 124.0,
#   'Vintage': 70,
#   'Response': 0},
#  {'id': 943,
#   'Gender': 'Female',
#   'Age': 42,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 43878.0,
#   'Policy_Sales_Channel': 26.0,
#   'Vintage': 59,
#   'Response': 0},
#  {'id': 944,
#   'Gender': 'Female',
#   'Age': 25,
#   'Driving_License': 1,
#   'Region_Code': 36.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 29430.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 271,
#   'Response': 0},
#  {'id': 945,
#   'Gender': 'Female',
#   'Age': 22,
#   'Driving_License': 1,
#   'Region_Code': 7.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 49396.0,
#   'Policy_Sales_Channel': 160.0,
#   'Vintage': 133,
#   'Response': 0},
#  {'id': 946,
#   'Gender': 'Female',
#   'Age': 42,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 23211.0,
#   'Policy_Sales_Channel': 26.0,
#   'Vintage': 113,
#   'Response': 0},
#  {'id': 947,
#   'Gender': 'Male',
#   'Age': 22,
#   'Driving_License': 1,
#   'Region_Code': 15.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 38356.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 258,
#   'Response': 0},
#  {'id': 948,
#   'Gender': 'Female',
#   'Age': 22,
#   'Driving_License': 1,
#   'Region_Code': 37.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 30266.0,
#   'Policy_Sales_Channel': 160.0,
#   'Vintage': 88,
#   'Response': 0},
#  {'id': 949,
#   'Gender': 'Male',
#   'Age': 20,
#   'Driving_License': 1,
#   'Region_Code': 36.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 41945.0,
#   'Policy_Sales_Channel': 160.0,
#   'Vintage': 50,
#   'Response': 0},
#  {'id': 950,
#   'Gender': 'Female',
#   'Age': 46,
#   'Driving_License': 1,
#   'Region_Code': 26.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 2630.0,
#   'Policy_Sales_Channel': 157.0,
#   'Vintage': 142,
#   'Response': 1},
#  {'id': 951,
#   'Gender': 'Female',
#   'Age': 22,
#   'Driving_License': 1,
#   'Region_Code': 45.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 21280.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 45,
#   'Response': 0},
#  {'id': 952,
#   'Gender': 'Female',
#   'Age': 22,
#   'Driving_License': 1,
#   'Region_Code': 26.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 33459.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 153,
#   'Response': 0},
#  {'id': 953,
#   'Gender': 'Male',
#   'Age': 45,
#   'Driving_License': 1,
#   'Region_Code': 46.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 13895.0,
#   'Policy_Sales_Channel': 124.0,
#   'Vintage': 113,
#   'Response': 0},
#  {'id': 954,
#   'Gender': 'Female',
#   'Age': 23,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 65093.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 240,
#   'Response': 0},
#  {'id': 955,
#   'Gender': 'Male',
#   'Age': 57,
#   'Driving_License': 1,
#   'Region_Code': 39.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 2630.0,
#   'Policy_Sales_Channel': 124.0,
#   'Vintage': 49,
#   'Response': 0},
#  {'id': 956,
#   'Gender': 'Male',
#   'Age': 20,
#   'Driving_License': 1,
#   'Region_Code': 11.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 29587.0,
#   'Policy_Sales_Channel': 160.0,
#   'Vintage': 187,
#   'Response': 0},
#  {'id': 957,
#   'Gender': 'Male',
#   'Age': 50,
#   'Driving_License': 1,
#   'Region_Code': 15.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 33666.0,
#   'Policy_Sales_Channel': 124.0,
#   'Vintage': 242,
#   'Response': 1},
#  {'id': 958,
#   'Gender': 'Female',
#   'Age': 28,
#   'Driving_License': 1,
#   'Region_Code': 30.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 30354.0,
#   'Policy_Sales_Channel': 26.0,
#   'Vintage': 232,
#   'Response': 0},
#  {'id': 959,
#   'Gender': 'Male',
#   'Age': 36,
#   'Driving_License': 1,
#   'Region_Code': 29.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '> 2 Years',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 28075.0,
#   'Policy_Sales_Channel': 156.0,
#   'Vintage': 230,
#   'Response': 0},
#  {'id': 960,
#   'Gender': 'Female',
#   'Age': 21,
#   'Driving_License': 1,
#   'Region_Code': 45.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 27546.0,
#   'Policy_Sales_Channel': 160.0,
#   'Vintage': 279,
#   'Response': 0},
#  {'id': 961,
#   'Gender': 'Female',
#   'Age': 20,
#   'Driving_License': 1,
#   'Region_Code': 30.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 35192.0,
#   'Policy_Sales_Channel': 160.0,
#   'Vintage': 25,
#   'Response': 0},
#  {'id': 962,
#   'Gender': 'Male',
#   'Age': 23,
#   'Driving_License': 1,
#   'Region_Code': 41.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 32978.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 112,
#   'Response': 0},
#  {'id': 963,
#   'Gender': 'Female',
#   'Age': 22,
#   'Driving_License': 1,
#   'Region_Code': 46.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 59086.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 238,
#   'Response': 0},
#  {'id': 964,
#   'Gender': 'Male',
#   'Age': 33,
#   'Driving_License': 1,
#   'Region_Code': 15.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 35268.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 268,
#   'Response': 0},
#  {'id': 965,
#   'Gender': 'Male',
#   'Age': 35,
#   'Driving_License': 1,
#   'Region_Code': 46.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 23146.0,
#   'Policy_Sales_Channel': 124.0,
#   'Vintage': 268,
#   'Response': 0},
#  {'id': 966,
#   'Gender': 'Female',
#   'Age': 25,
#   'Driving_License': 1,
#   'Region_Code': 8.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 36341.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 65,
#   'Response': 0},
#  {'id': 967,
#   'Gender': 'Female',
#   'Age': 27,
#   'Driving_License': 1,
#   'Region_Code': 8.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 42963.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 175,
#   'Response': 0},
#  {'id': 968,
#   'Gender': 'Male',
#   'Age': 47,
#   'Driving_License': 1,
#   'Region_Code': 3.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 24495.0,
#   'Policy_Sales_Channel': 7.0,
#   'Vintage': 284,
#   'Response': 0},
#  {'id': 969,
#   'Gender': 'Female',
#   'Age': 25,
#   'Driving_License': 1,
#   'Region_Code': 12.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 23262.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 69,
#   'Response': 0},
#  {'id': 970,
#   'Gender': 'Male',
#   'Age': 33,
#   'Driving_License': 1,
#   'Region_Code': 36.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 26910.0,
#   'Policy_Sales_Channel': 124.0,
#   'Vintage': 31,
#   'Response': 0},
#  {'id': 971,
#   'Gender': 'Male',
#   'Age': 34,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 31177.0,
#   'Policy_Sales_Channel': 26.0,
#   'Vintage': 103,
#   'Response': 1},
#  {'id': 972,
#   'Gender': 'Male',
#   'Age': 52,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 50851.0,
#   'Policy_Sales_Channel': 124.0,
#   'Vintage': 285,
#   'Response': 1},
#  {'id': 973,
#   'Gender': 'Male',
#   'Age': 32,
#   'Driving_License': 1,
#   'Region_Code': 8.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 30505.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 181,
#   'Response': 0},
#  {'id': 974,
#   'Gender': 'Male',
#   'Age': 40,
#   'Driving_License': 1,
#   'Region_Code': 8.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 49097.0,
#   'Policy_Sales_Channel': 26.0,
#   'Vintage': 208,
#   'Response': 0},
#  {'id': 975,
#   'Gender': 'Male',
#   'Age': 57,
#   'Driving_License': 1,
#   'Region_Code': 46.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 2630.0,
#   'Policy_Sales_Channel': 11.0,
#   'Vintage': 269,
#   'Response': 0},
#  {'id': 976,
#   'Gender': 'Female',
#   'Age': 23,
#   'Driving_License': 1,
#   'Region_Code': 46.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 47385.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 277,
#   'Response': 0},
#  {'id': 977,
#   'Gender': 'Male',
#   'Age': 33,
#   'Driving_License': 1,
#   'Region_Code': 10.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 21928.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 58,
#   'Response': 0},
#  {'id': 978,
#   'Gender': 'Female',
#   'Age': 67,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 2630.0,
#   'Policy_Sales_Channel': 42.0,
#   'Vintage': 138,
#   'Response': 0},
#  {'id': 979,
#   'Gender': 'Female',
#   'Age': 33,
#   'Driving_License': 1,
#   'Region_Code': 46.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 2630.0,
#   'Policy_Sales_Channel': 156.0,
#   'Vintage': 116,
#   'Response': 1},
#  {'id': 980,
#   'Gender': 'Male',
#   'Age': 48,
#   'Driving_License': 1,
#   'Region_Code': 27.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 32645.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 182,
#   'Response': 0},
#  {'id': 981,
#   'Gender': 'Male',
#   'Age': 35,
#   'Driving_License': 1,
#   'Region_Code': 32.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 34062.0,
#   'Policy_Sales_Channel': 163.0,
#   'Vintage': 236,
#   'Response': 1},
#  {'id': 982,
#   'Gender': 'Male',
#   'Age': 38,
#   'Driving_License': 1,
#   'Region_Code': 36.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 37742.0,
#   'Policy_Sales_Channel': 26.0,
#   'Vintage': 295,
#   'Response': 1},
#  {'id': 983,
#   'Gender': 'Male',
#   'Age': 24,
#   'Driving_License': 1,
#   'Region_Code': 17.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 29625.0,
#   'Policy_Sales_Channel': 83.0,
#   'Vintage': 286,
#   'Response': 0},
#  {'id': 984,
#   'Gender': 'Female',
#   'Age': 23,
#   'Driving_License': 1,
#   'Region_Code': 47.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 29431.0,
#   'Policy_Sales_Channel': 151.0,
#   'Vintage': 257,
#   'Response': 0},
#  {'id': 985,
#   'Gender': 'Male',
#   'Age': 23,
#   'Driving_License': 1,
#   'Region_Code': 16.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 2630.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 126,
#   'Response': 1},
#  {'id': 986,
#   'Gender': 'Female',
#   'Age': 25,
#   'Driving_License': 1,
#   'Region_Code': 46.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 20804.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 204,
#   'Response': 0},
#  {'id': 987,
#   'Gender': 'Female',
#   'Age': 23,
#   'Driving_License': 1,
#   'Region_Code': 16.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 2630.0,
#   'Policy_Sales_Channel': 26.0,
#   'Vintage': 145,
#   'Response': 0},
#  {'id': 988,
#   'Gender': 'Male',
#   'Age': 23,
#   'Driving_License': 1,
#   'Region_Code': 47.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 31231.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 175,
#   'Response': 0},
#  {'id': 989,
#   'Gender': 'Male',
#   'Age': 48,
#   'Driving_License': 1,
#   'Region_Code': 3.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 32485.0,
#   'Policy_Sales_Channel': 124.0,
#   'Vintage': 12,
#   'Response': 1},
#  {'id': 990,
#   'Gender': 'Female',
#   'Age': 51,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 37768.0,
#   'Policy_Sales_Channel': 25.0,
#   'Vintage': 69,
#   'Response': 0},
#  {'id': 991,
#   'Gender': 'Female',
#   'Age': 43,
#   'Driving_License': 1,
#   'Region_Code': 3.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 30437.0,
#   'Policy_Sales_Channel': 26.0,
#   'Vintage': 208,
#   'Response': 0},
#  {'id': 992,
#   'Gender': 'Male',
#   'Age': 66,
#   'Driving_License': 1,
#   'Region_Code': 3.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 2630.0,
#   'Policy_Sales_Channel': 26.0,
#   'Vintage': 240,
#   'Response': 0},
#  {'id': 993,
#   'Gender': 'Female',
#   'Age': 25,
#   'Driving_License': 1,
#   'Region_Code': 3.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 22102.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 163,
#   'Response': 0},
#  {'id': 994,
#   'Gender': 'Female',
#   'Age': 27,
#   'Driving_License': 1,
#   'Region_Code': 10.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 30517.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 125,
#   'Response': 0},
#  {'id': 995,
#   'Gender': 'Female',
#   'Age': 58,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 42064.0,
#   'Policy_Sales_Channel': 26.0,
#   'Vintage': 163,
#   'Response': 0},
#  {'id': 996,
#   'Gender': 'Female',
#   'Age': 25,
#   'Driving_License': 1,
#   'Region_Code': 35.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 41195.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 148,
#   'Response': 0},
#  {'id': 997,
#   'Gender': 'Male',
#   'Age': 31,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 38881.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 120,
#   'Response': 0},
#  {'id': 998,
#   'Gender': 'Male',
#   'Age': 31,
#   'Driving_License': 1,
#   'Region_Code': 41.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 18987.0,
#   'Policy_Sales_Channel': 152.0,
#   'Vintage': 100,
#   'Response': 1},
#  {'id': 999,
#   'Gender': 'Female',
#   'Age': 43,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 55924.0,
#   'Policy_Sales_Channel': 26.0,
#   'Vintage': 216,
#   'Response': 1},
#  {'id': 1000,
#   'Gender': 'Female',
#   'Age': 21,
#   'Driving_License': 1,
#   'Region_Code': 46.0,
#   'Previously_Insured': 1,
#   'Vehicle_Age': '< 1 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 29298.0,
#   'Policy_Sales_Channel': 160.0,
#   'Vintage': 37,
#   'Response': 0},
#  ...]

# %%
DB_NAME = 'Proj1'
COLLECTION_NAME = 'Proj1-Data'
CONNECTION_URL = "mongodb+srv://samalrdago:0eR6RwIw0kKVrMmO@cluster0.pjknlnb.mongodb.net/retryWrites=true&w=majority&appName=Cluster0"

# %%
client  = pymongo.MongoClient(CONNECTION_URL)
data_base = client[DB_NAME]
collection = data_base[COLLECTION_NAME]

# %%
rec = collection.insert_many(data)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 rec = collection.insert_many(data)
#
# File c:\Users\mdriz\Youtube tut\mlops\vehical-insurance-domain\venv\Lib\site-packages\pymongo\_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File c:\Users\mdriz\Youtube tut\mlops\vehical-insurance-domain\venv\Lib\site-packages\pymongo\synchronous\collection.py:975, in Collection.insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     973 blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
#     974 blk.ops = list(gen())
# --> 975 blk.execute(write_concern, session, _Op.INSERT)
#     976 return InsertManyResult(inserted_ids, write_concern.acknowledged)
#
# File c:\Users\mdriz\Youtube tut\mlops\vehical-insurance-domain\venv\Lib\site-packages\pymongo\synchronous\bulk.py:751, in _Bulk.execute(self, write_concern, session, operation)
#     749         return None
#     750 else:
# --> 751     return self.execute_command(generator, write_concern, session, operation)
#
# File c:\Users\mdriz\Youtube tut\mlops\vehical-insurance-domain\venv\Lib\site-packages\pymongo\synchronous\bulk.py:604, in _Bulk.execute_command(self, generator, write_concern, session, operation)
#     593     self._execute_command(
#     594         generator,
#     595         write_concern,
#    (...)    600         full_result,
#     601     )
#     603 client = self.collection.database.client
# --> 604 _ = client._retryable_write(
#     605     self.is_retryable,
#     606     retryable_bulk,
#     607     session,
#     608     operation,
#     609     bulk=self,  # type: ignore[arg-type]
#     610     operation_id=op_id,
#     611 )
#     613 if full_result["writeErrors"] or full_result["writeConcernErrors"]:
#     614     _raise_bulk_write_error(full_result)
#
# File c:\Users\mdriz\Youtube tut\mlops\vehical-insurance-domain\venv\Lib\site-packages\pymongo\synchronous\mongo_client.py:2061, in MongoClient._retryable_write(self, retryable, func, session, operation, bulk, operation_id)
#    2047 """Execute an operation with consecutive retries if possible
#    2048
#    2049 Returns func()'s return value on success. On error retries the same
#    (...)   2058 :param bulk: bulk abstraction to execute operations in bulk, defaults to None
#    2059 """
#    2060 with self._tmp_session(session) as s:
# -> 2061     return self._retry_with_session(retryable, func, s, bulk, operation, operation_id)
#
# File c:\Users\mdriz\Youtube tut\mlops\vehical-insurance-domain\venv\Lib\site-packages\pymongo\synchronous\mongo_client.py:1947, in MongoClient._retry_with_session(self, retryable, func, session, bulk, operation, operation_id)
#    1942 # Ensure that the options supports retry_writes and there is a valid session not in
#    1943 # transaction, otherwise, we will not support retry behavior for this txn.
#    1944 retryable = bool(
#    1945     retryable and self.options.retry_writes and session and not session.in_transaction
#    1946 )
# -> 1947 return self._retry_internal(
#    1948     func=func,
#    1949     session=session,
#    1950     bulk=bulk,
#    1951     operation=operation,
#    1952     retryable=retryable,
#    1953     operation_id=operation_id,
#    1954 )
#
# File c:\Users\mdriz\Youtube tut\mlops\vehical-insurance-domain\venv\Lib\site-packages\pymongo\_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File c:\Users\mdriz\Youtube tut\mlops\vehical-insurance-domain\venv\Lib\site-packages\pymongo\synchronous\mongo_client.py:1993, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1956 @_csot.apply
#    1957 def _retry_internal(
#    1958     self,
#    (...)   1967     operation_id: Optional[int] = None,
#    1968 ) -> T:
#    1969     """Internal retryable helper for all client transactions.
#    1970
#    1971     :param func: Callback function we want to retry
#    (...)   1980     :return: Output of the calling func()
#    1981     """
#    1982     return _ClientConnectionRetryable(
#    1983         mongo_client=self,
#    1984         func=func,
#    1985         bulk=bulk,
#    1986         operation=operation,
#    1987         is_read=is_read,
#    1988         session=session,
#    1989         read_pref=read_pref,
#    1990         address=address,
#    1991         retryable=retryable,
#    1992         operation_id=operation_id,
# -> 1993     ).run()
#
# File c:\Users\mdriz\Youtube tut\mlops\vehical-insurance-domain\venv\Lib\site-packages\pymongo\synchronous\mongo_client.py:2730, in _ClientConnectionRetryable.run(self)
#    2728 self._check_last_error(check_csot=True)
#    2729 try:
# -> 2730     return self._read() if self._is_read else self._write()
#    2731 except ServerSelectionTimeoutError:
#    2732     # The application may think the write was never attempted
#    2733     # if we raise ServerSelectionTimeoutError on the retry
#    2734     # attempt. Raise the original exception instead.
#    2735     self._check_last_error()
#
# File c:\Users\mdriz\Youtube tut\mlops\vehical-insurance-domain\venv\Lib\site-packages\pymongo\synchronous\mongo_client.py:2841, in _ClientConnectionRetryable._write(self)
#    2839 is_mongos = False
#    2840 self._server = self._get_server()
# -> 2841 with self._client._checkout(self._server, self._session) as conn:
#    2842     max_wire_version = conn.max_wire_version
#    2843     sessions_supported = (
#    2844         self._session
#    2845         and self._server.description.retryable_writes_supported
#    2846         and conn.supports_sessions
#    2847     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\mdriz\Youtube tut\mlops\vehical-insurance-domain\venv\Lib\site-packages\pymongo\synchronous\mongo_client.py:1756, in MongoClient._checkout(self, server, session)
#    1754     yield session._pinned_connection
#    1755     return
# -> 1756 with server.checkout(handler=err_handler) as conn:
#    1757     # Pin this session to the selected server or connection.
#    1758     if (
#    1759         in_txn
#    1760         and session
#    (...)   1765         )
#    1766     ):
#    1767         session._pin(server, conn)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\mdriz\Youtube tut\mlops\vehical-insurance-domain\venv\Lib\site-packages\pymongo\synchronous\pool.py:1119, in Pool.checkout(self, handler)
#    1110 if self.enabled_for_logging and _CONNECTION_LOGGER.isEnabledFor(logging.DEBUG):
#    1111     _debug_log(
#    1112         _CONNECTION_LOGGER,
#    1113         message=_ConnectionStatusMessage.CHECKOUT_STARTED,
#    (...)   1116         serverPort=self.address[1],
#    1117     )
# -> 1119 conn = self._get_conn(checkout_started_time, handler=handler)
#    1121 duration = time.monotonic() - checkout_started_time
#    1122 if self.enabled_for_cmap:
#
# File c:\Users\mdriz\Youtube tut\mlops\vehical-insurance-domain\venv\Lib\site-packages\pymongo\synchronous\pool.py:1281, in Pool._get_conn(self, checkout_started_time, handler)
#    1279 else:  # We need to create a new connection
#    1280     try:
# -> 1281         conn = self.connect(handler=handler)
#    1282     finally:
#    1283         with self._max_connecting_cond:
#
# File c:\Users\mdriz\Youtube tut\mlops\vehical-insurance-domain\venv\Lib\site-packages\pymongo\synchronous\pool.py:1073, in Pool.connect(self, handler)
#    1070     if handler:
#    1071         handler.contribute_socket(conn, completed_handshake=False)
# -> 1073     conn.authenticate()
#    1074 # Catch KeyboardInterrupt, CancelledError, etc. and cleanup.
#    1075 except BaseException:
#
# File c:\Users\mdriz\Youtube tut\mlops\vehical-insurance-domain\venv\Lib\site-packages\pymongo\synchronous\pool.py:526, in Connection.authenticate(self, reauthenticate)
#     523 if creds:
#     524     from pymongo.synchronous import auth
# --> 526     auth.authenticate(creds, self, reauthenticate=reauthenticate)
#     527 self.ready = True
#     528 duration = time.monotonic() - self.creation_time
#
# File c:\Users\mdriz\Youtube tut\mlops\vehical-insurance-domain\venv\Lib\site-packages\pymongo\synchronous\auth.py:450, in authenticate(credentials, conn, reauthenticate)
#     448     _authenticate_oidc(credentials, conn, reauthenticate)
#     449 else:
# --> 450     auth_func(credentials, conn)
#
# File c:\Users\mdriz\Youtube tut\mlops\vehical-insurance-domain\venv\Lib\site-packages\pymongo\synchronous\auth.py:355, in _authenticate_default(credentials, conn)
#     353         return _authenticate_scram(credentials, conn, "SCRAM-SHA-256")
#     354     else:
# --> 355         return _authenticate_scram(credentials, conn, "SCRAM-SHA-1")
#     356 else:
#     357     return _authenticate_scram(credentials, conn, "SCRAM-SHA-1")
#
# File c:\Users\mdriz\Youtube tut\mlops\vehical-insurance-domain\venv\Lib\site-packages\pymongo\synchronous\auth.py:135, in _authenticate_scram(credentials, conn, mechanism)
#     128 server_sig = standard_b64encode(_hmac(server_key, auth_msg, digestmod).digest())
#     130 cmd = {
#     131     "saslContinue": 1,
#     132     "conversationId": res["conversationId"],
#     133     "payload": Binary(client_final),
#     134 }
# --> 135 res = conn.command(source, cmd)
#     137 parsed = _parse_scram_response(res["payload"])
#     138 if not hmac.compare_digest(parsed[b"v"], server_sig):
#
# File c:\Users\mdriz\Youtube tut\mlops\vehical-insurance-domain\venv\Lib\site-packages\pymongo\synchronous\helpers.py:47, in _handle_reauth.<locals>.inner(*args, **kwargs)
#      44 from pymongo.synchronous.pool import Connection
#      46 try:
# ---> 47     return func(*args, **kwargs)
#      48 except OperationFailure as exc:
#      49     if no_reauth:
#
# File c:\Users\mdriz\Youtube tut\mlops\vehical-insurance-domain\venv\Lib\site-packages\pymongo\synchronous\pool.py:414, in Connection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     412     self._raise_if_not_writable(unacknowledged)
#     413 try:
# --> 414     return command(
#     415         self,
#     416         dbname,
#     417         spec,
#     418         self.is_mongos,
#     419         read_preference,
#     420         codec_options,
#     421         session,
#     422         client,
#     423         check,
#     424         allowable_errors,
#     425         self.address,
#     426         listeners,
#     427         self.max_bson_size,
#     428         read_concern,
#     429         parse_write_concern_error=parse_write_concern_error,
#     430         collation=collation,
#     431         compression_ctx=self.compression_context,
#     432         use_op_msg=self.op_msg_enabled,
#     433         unacknowledged=unacknowledged,
#     434         user_fields=user_fields,
#     435         exhaust_allowed=exhaust_allowed,
#     436         write_concern=write_concern,
#     437     )
#     438 except (OperationFailure, NotPrimaryError):
#     439     raise
#
# File c:\Users\mdriz\Youtube tut\mlops\vehical-insurance-domain\venv\Lib\site-packages\pymongo\synchronous\network.py:212, in command(conn, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     210             client._process_response(response_doc, session)
#     211         if check:
# --> 212             helpers_shared._check_command_response(
#     213                 response_doc,
#     214                 conn.max_wire_version,
#     215                 allowable_errors,
#     216                 parse_write_concern_error=parse_write_concern_error,
#     217             )
#     218 except Exception as exc:
#     219     duration = datetime.datetime.now() - start
#
# File c:\Users\mdriz\Youtube tut\mlops\vehical-insurance-domain\venv\Lib\site-packages\pymongo\helpers_shared.py:250, in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error)
#     247 elif code == 43:
#     248     raise CursorNotFound(errmsg, code, response, max_wire_version)
# --> 250 raise OperationFailure(errmsg, code, response, max_wire_version)
#
# OperationFailure: bad auth : authentication failed, full error: {'ok': 0, 'errmsg': 'bad auth : authentication failed', 'code': 8000, 'codeName': 'AtlasError'}
